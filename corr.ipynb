# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
from ydata_profiling import ProfileReport
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})
sns.set_style('whitegrid')

# %%
df_riskFactor = pd.read_csv("data/number-of-deaths-by-risk-factor.csv")
df_riskFactor.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths that are from all causes attributed to high systolic blood pressure, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to diet high in sodium, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to diet low in whole grains, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to alcohol use, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to diet low in fruits, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to unsafe water source, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to secondhand smoke, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to low birth weight, in both sexes aged all ages',
#        'Deaths that are from all causes attributed to child wasting, in both sexes aged all ages',
# ...

# %%
df_riskFactor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 31 columns):
#  #   Column                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                               --------------  -----
#  0   Entity                                                                                                               6840 non-null   object
#  1   Code                                                                                                                 6150 non-null   object
#  2   Year                                                                                                                 6840 non-null   int64
#  3   Deaths that are from all causes attributed to high systolic blood pressure, in both sexes aged all ages              6840 non-null   float64
# ...

# %%
df_riskFactorSelection=df_riskFactor[["Entity","Year","Deaths that are from all causes attributed to low physical activity, in both sexes aged all ages","Deaths that are from all causes attributed to high ldl cholesterol, in both sexes aged all ages","Deaths that are from all causes attributed to secondhand smoke, in both sexes aged all ages","Deaths that are from all causes attributed to alcohol use, in both sexes aged all ages"]]

# %%
listaPaises=list(df_riskFactorSelection["Entity"].unique())

# %%
df_riskFactorSelection.head(5)
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Deaths that are from all causes attributed to low physical activity, in both sexes aged all ages  \
# 0                                          2636.6455
# 1                                          2651.8865
# 2                                          2687.9224
# 3                                          2744.3599
# 4                                          2805.2195
#
#    Deaths that are from all causes attributed to high ldl cholesterol, in both sexes aged all ages  \
# 0                                         12704.7810
# 1                                         12843.5130
# 2                                         13125.6210
# 3                                         13501.3545
# 4                                         13872.5840
#
# ...

# %%
sns.heatmap(df_riskFactorSelection.corr(numeric_only=True), annot=True,vmax=1,vmin=-1,cmap="Spectral", linecolor="black",linewidths=1);

# %%
profile = ProfileReport(df_riskFactorSelection, title="Profiling Report")
profile.to_file("your_report.html")
# Out:
# C:\Users\nicoc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ydata_profiling\utils\dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result_add = seasonal_decompose(df[['value']], model='additive', extrapolate_trend='freq')

# Plot
plt.rcParams.update({'figure.figsize': (6,6)})
result_add.plot();

# %%
df_adoption = pd.read_csv("data/ict-adoption.csv")
df_adoption.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Fixed telephone subscriptions',
#        'Fixed broadband subscriptions', 'Mobile cellular subscriptions',
#        'Number of Internet users'],
#       dtype='object')

# %%
df_adoption
# Out:
#             Entity Code  Year  Fixed telephone subscriptions  \
# 0      Afghanistan  AFG  1960                         7700.0
# 1      Afghanistan  AFG  1961                         7700.0
# 2      Afghanistan  AFG  1962                         7700.0
# 3      Afghanistan  AFG  1963                         7700.0
# 4      Afghanistan  AFG  1964                         7700.0
# ...            ...  ...   ...                            ...
# 12933     Zimbabwe  ZWE  2017                       264150.0
# 12934     Zimbabwe  ZWE  2018                       268849.0
# 12935     Zimbabwe  ZWE  2019                       265734.0
# 12936     Zimbabwe  ZWE  2020                       252067.0
# 12937     Zimbabwe  ZWE  2021                       243421.0
#
#        Fixed broadband subscriptions  Mobile cellular subscriptions  \
# 0                                NaN                            0.0
# 1                                NaN                            NaN
# ...

# %%
df_adoption.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12938 entries, 0 to 12937
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Entity                         12938 non-null  object
#  1   Code                           11929 non-null  object
#  2   Year                           12938 non-null  int64
#  3   Fixed telephone subscriptions  12047 non-null  float64
#  4   Fixed broadband subscriptions  4037 non-null   float64
#  5   Mobile cellular subscriptions  10731 non-null  float64
#  6   Number of Internet users       6406 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 707.7+ KB

# %%
profile = ProfileReport(df_riskFactorSelection, title="Profiling Report")
profile.to_file("df_adoption.html")
# Out:
# C:\Users\nicoc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ydata_profiling\utils\dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_obesity = pd.read_csv("data/share-of-deaths-obesity.csv")
df_obesity.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Share of total deaths that are from all causes attributed to high body-mass index, in both sexes aged age-standardized'],
#       dtype='object')

# %%
profile = ProfileReport(df_riskFactorSelection, title="Profiling Report")
profile.to_file("df_obesity.html")
# Out:
# C:\Users\nicoc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ydata_profiling\utils\dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_socialMedia = pd.read_csv("data/SocialMediaUsersDataset.csv")
df_socialMedia.columns
# Out:
# Index(['UserID', 'Name', 'Gender', 'DOB', 'Interests', 'City', 'Country'], dtype='object')

# %%
profile = ProfileReport(df_socialMedia, title="Profiling Report")
profile.to_file("df_socialMedia.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\nicoc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Female'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
hourlyIntensities_merged = pd.read_csv("data/hourlyIntensities_merged.csv")
hourlyIntensities_merged
# Out:
#                Id           ActivityHour  TotalIntensity  AverageIntensity
# 0      1503960366  4/12/2016 12:00:00 AM              20          0.333333
# 1      1503960366   4/12/2016 1:00:00 AM               8          0.133333
# 2      1503960366   4/12/2016 2:00:00 AM               7          0.116667
# 3      1503960366   4/12/2016 3:00:00 AM               0          0.000000
# 4      1503960366   4/12/2016 4:00:00 AM               0          0.000000
# ...           ...                    ...             ...               ...
# 22094  8877689391  5/12/2016 10:00:00 AM              12          0.200000
# 22095  8877689391  5/12/2016 11:00:00 AM              29          0.483333
# 22096  8877689391  5/12/2016 12:00:00 PM              93          1.550000
# 22097  8877689391   5/12/2016 1:00:00 PM               6          0.100000
# 22098  8877689391   5/12/2016 2:00:00 PM               9          0.150000
#
# [22099 rows x 4 columns]

# %%
sns.heatmap(hourlyIntensities_merged.corr(numeric_only=True), annot=True,vmax=1,vmin=-1,cmap="Spectral", linecolor="black",linewidths=1);

# %%
dailyActivity_merged = pd.read_csv("data/dailyActivity_merged.csv")
dailyActivity_merged
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
dailyActivity_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
sns.heatmap(dailyActivity_merged.corr(numeric_only=True), annot=True,vmax=1,vmin=-1,cmap="Spectral", linecolor="black",linewidths=1);

# %%
adtivityPoints = pd.read_csv("data/adtivityPoints.csv",sep=";")
adtivityPoints.columns
# Out:
# Index(['Company name', 'Device name', 'Crowd funded', 'County of origin',
#        'Release year', 'Form factor', 'Accelerometer', 'Gyroscope',
#        'Magnetometer', 'Barometer', 'GPS', 'PPG'],
#       dtype='object')

# %%
adtivityPoints.head(15)
# Out:
#       Company name           Device name  Crowd funded County of origin  \
# 0          Actofit       Fitness Tracker          True            India
# 1           Adidas     MiCoach Fit Smart         False          Germany
# 2           Adidas     MiCoach Smart Run         False          Germany
# 3            Airon                   105         False            Norge
# 4          Alcatel     Onetouch GO Watch         False            China
# 5          Alcatel        Onetouch Watch         False            China
# 6          Allview                Allfit         False          Romania
# 7          Allview              Allwatch         False          Romania
# 8          Allview            Allwatch S         False          Romania
# 9   Ambit Networks  AmbyGear Smart Watch         False              USA
# 10          Amiigo             Wristband          True              USA
# 11           Apple                 Watch         False              USA
# ...
